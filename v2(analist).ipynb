# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasMirandaVS/estudos_R/blob/main/v2(analist).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = 'LUCAS MIRANDA'
Title = 'Analista de Dados'
Contact = 'Rio de Janeiro, RJ\n(31)99798-0419'
cont2 = '\nlmiranda685@gmail.com\nlinkedin.com/in/lucas-miranda-ds\ngithub.com/LucasMirandaVS'
ProjectsHeader = 'PROJETOS'
ProjectThreeTitle = 'Análise de Sentimento de tweets'
ProjectThreeDesc = '-Coletei tweets pela API do twitter e realizei uma análise exploratória;\n-Limpei e visualizei os dados usando os pacotes httpuv, reshape2, rtweet,\n stopwords, dplyr, tidyr, tidytext, wordcloud, stringr e textdata em R\n-Link para o projeto: \ngithub.com/LucasMirandaVS/projeto_analise_sentimento_twitter'
ProjectTwoTitle = 'Análise de dados de Filmes com Banco de dados SQLite'
ProjectTwoDesc = '-Projeto realizado com linguagem Python e queries SQL; \n-Limpei e visualizei os dados com Pandas e matplotlib e analisei dados\n sobre os filmes do IMDB usando queries SQL.\n-Link para o projeto: \ngithub.com/LucasMirandaVS/estudos_python//eda_em_banco_de_dados_sqlite' 
ProjectOneTitle = 'Web scrapping e análise de dados Financeiros com Python'
ProjectOneDesc = '-Limpeza de dados para análise usando o Python;\n-Usei os pacotes numpy, pandas, matplotlib e yFinance para manipular e analisar \ndados de ações na BOVESPA;\n-Link para o projeto: \ngithub.com/LucasMirandaVS/(Matplotlib)Analisando_dados_financeiros'
EduHeader = 'EDUCAÇÃO'
EduOneTitle = 'UNIVERSIDADE FEDERAL DE OURO PRETO\n- Mestre em Economia Aplicada'
EduOneTime = '2020-2022'
EduTwoTitle = 'UNIVERSIDADE FEDERAL DE OURO PRETO\n- Bacharel em Ciências Econômicas'
EduTwoTime = '2016-2019'
SkillsHeader = 'Skills'
SkillsDesc = '- Python\n- Pandas\n- NumPy\n- Visualização de Dados\n- Data Cleaning\n- R\n- SQL\n- APIs\n- Estatística e Probabilidade\n- Manipulação de Dados\n- Excel\n- Inglês Fluente'
CodeTitle = 'Outros Projetos:'

# %%
# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.950), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(cont2, (.7, .906),weight = 'regular', fontsize = 8, color = '#58C1B2')
# Projetos
plt.annotate(ProjectsHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ProjectOneTitle, (.02,.835), weight='bold', fontsize=10)
plt.annotate(ProjectOneDesc, (.04,.758), weight='regular', fontsize=9)
plt.annotate(ProjectTwoTitle, (.02,.735), weight='bold', fontsize=10)
plt.annotate(ProjectTwoDesc, (.04,.66), weight='regular', fontsize=9)
plt.annotate(ProjectThreeTitle, (.02,.625), weight='bold', fontsize=10)
plt.annotate(ProjectThreeDesc, (.04,.55), weight='regular', fontsize=9)

# EDU
plt.annotate(EduHeader, (.02,.485), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.440), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.415), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoTitle, (.02,.340), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.31), weight='regular', fontsize=9, alpha=.6)
plt.annotate(SkillsHeader, (.7,.8), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.56), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(CodeTitle, (.7,.2), weight='bold', fontsize=10, color='#ffffff')


from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('qrbom.png')
imagebox = OffsetImage(arr_code, zoom=0.07)
ab = AnnotationBbox(imagebox, (0.8, 0.12))
ax.add_artist(ab)


# Salvando o CV
plt.savefig('CV.pdf', dpi=300, bbox_inches='tight')
